# %%
#%tensorflow_version 2.x  # this line is not required unless you are in a notebook
from keras.preprocessing import sequence
import keras
import tensorflow as tf
import os
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-4996ee3d8d09> in <module>
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/gdrive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
#path_to_file = 'FatherTime_Dialog_clean.txt'
#Length of text: 16995 characters
path_to_file = 'cleaner_script.txt'
#Length of text: 319880 characters

# %%
# Read, then decode for py2 compat.
text = open(path_to_file, 'rb').read().decode(encoding='utf-8')
# length of text is the number of characters in it
print ('Length of text: {} characters'.format(len(text)))
# Out:
# Length of text: 319880 characters

# %%
#sort all the words and number them 0-'n' based on this order, if we had to rebuild this sequence, it'll be the same
vocab = sorted(set(text))
char2idx = {u:i for i, u in enumerate(vocab)}
idx2char = np.array(vocab)

def text_to_int(text):
  return np.array([char2idx[c] for c in text])

def int_to_text(ints):
  try:
    ints = ints.numpy()
  except:
    pass
  return ''.join(idx2char[ints])

def build_model(vocab_size, embedding_dim, rnn_units, batch_size):
  model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim,
                              batch_input_shape=[batch_size, None]),
    tf.keras.layers.LSTM(rnn_units,
                        return_sequences=True,
                        stateful=True,
                        recurrent_initializer='glorot_uniform'),
    tf.keras.layers.Dense(vocab_size)
  ])
  return model

def loss(labels, logits):
  return tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)

# %%
# lets look at how part of our text is encoded
text_as_int = text_to_int(text)
print("Text:", text[:13])
print("Encoded:", text_to_int(text[:13]))
print(int_to_text(text_as_int[:13]))
# Out:
# Text: A Manikin mus
# Encoded: [22  2 34 47 60 55 57 55 60  2 59 67 65]
# A Manikin mus

# %% [markdown]
# we need to split our text data from above into many shorter sequences that we can pass to the model as training examples.
# The training examples we will prepapre will use a seq_length sequence as input and a seq_length sequence as the output where that sequence is the original sequence shifted one letter to the right. For example:
# input: Hell | output: ello

# %%
seq_length = 70  # length of sequence for a training example default is 100
examples_per_epoch = len(text)//(seq_length+1)

# Create training examples / targets
char_dataset = tf.data.Dataset.from_tensor_slices(text_as_int)

# %%
sequences = char_dataset.batch(seq_length+1, drop_remainder=True)
#when we run out of letters, we drop the rest

# %%
def split_input_target(chunk):  # for the example: hello
    input_text = chunk[:-1]  # hell
    target_text = chunk[1:]  # ello
    return input_text, target_text  # hell, ello

def split_input_left(chunk):  # for the example: hello
    #input_text = chunk[1:]  # ello
    #target_text = chunk[:-1]  # hell
    #LSTM doesn't flow backwards well, so we'll train our model with reversed text
    revChunk = tf.reverse(chunk, [-1])
    input_text = revChunk[:-1] #olle
    target_text = revChunk[1:] #lleh
    return input_text, target_text  # olle, lleh

dataset = sequences.map(split_input_target)  # we use map to apply the above function to every entry
dataset_left = sequences.map(split_input_left)  # we use map to apply the above function to every entry

# %%
#text to right
for x, y in dataset.take(147):
  print("\n\nEXAMPLE\n")
  print("INPUT")
  print(int_to_text(x))
  print("\nOUTPUT")
  print(int_to_text(y))
# Out:
# EXAMPLE
#
# INPUT
# A Manikin must have stolen it and fled, in hopes of returning to the V
#
# OUTPUT
#  Manikin must have stolen it and fled, in hopes of returning to the Vo
#
#
# EXAMPLE
#
# INPUT
# rtex World.
# A big group of Manikins went downstairs.
# A bunch of Mant
#
# OUTPUT
# tex World.
# A big group of Manikins went downstairs.
# A bunch of Mantr
#
#
# EXAMPLE
#
# INPUT
# a demons came through here on their way to fight Nihilo.
# A buncha Man
#
# OUTPUT
#  demons came through here on their way to fight Nihilo.
# A buncha Mani
#
#
# EXAMPLE
#
# INPUT
# kins just walked right in there!
# A buncha people were killed. You cou
#
# OUTPUT
# ins just walked right in there!
# A buncha people were killed. You coul
#
#
# EXAMPLE
#
# INPUT
# d hear the sirens wailing all night long.
# A ceremony is about to star
#
# OUTPUT
#  hear the sirens wailing all night long.
# A ceremony is about to start
#
#
# EXAMPLE
#
# INPUT
# . It seems very fishy indeed
# A ceremony is being prepared. It seems f
#
# OUTPUT
#  It seems very fishy indeed
# A ceremony is being prepared. It seems fi
#
#
# EXAMPLE
#
# INPUT
# shy
# A complete circle of stillness, in harmony with the workings of t
#
# OUTPUT
# hy
# A complete circle of stillness, in harmony with the workings of ti
#
#
# EXAMPLE
#
# INPUT
# me
# A demon born in exchange for the world
# A demon girl is attacking
#
# OUTPUT
# e
# A demon born in exchange for the world
# A demon girl is attacking M
#
#
# EXAMPLE
#
# INPUT
# ifunashiro!
# A demon hiring a demon slayer
# A demon just won his case,
#
# OUTPUT
# funashiro!
# A demon hiring a demon slayer
# A demon just won his case,
#
#
# EXAMPLE
#
# INPUT
# and was set free.
# A demon who can help take me to .
# A demon with the
#
# OUTPUT
# nd was set free.
# A demon who can help take me to .
# A demon with the
#
#
# EXAMPLE
#
# INPUT
# strength to become the champion of chaos
# A demon-like girl came to st
#
# OUTPUT
# trength to become the champion of chaos
# A demon-like girl came to ste
#
#
# EXAMPLE
#
# INPUT
# al our Magatsuhi
# A game's no fun if you don't know the rules. So, her
#
# OUTPUT
# l our Magatsuhi
# A game's no fun if you don't know the rules. So, here
#
#
# EXAMPLE
#
# INPUT
# 's the deal
# A ghost riding a motorcycle!! I don't think he's even lic
#
# OUTPUT
# s the deal
# A ghost riding a motorcycle!! I don't think he's even lice
#
#
# EXAMPLE
#
# INPUT
# nsed!!
# A guy with a strong will is going to change this chaotic world
#
# OUTPUT
# sed!!
# A guy with a strong will is going to change this chaotic world
#
#
# EXAMPLE
#
# INPUT
#
# A handsome demon like you deserves a major discount!
# A handsome demo
#
# OUTPUT
# A handsome demon like you deserves a major discount!
# A handsome demon
#
#
# EXAMPLE
#
# INPUT
#  like you deserves a major discount! *wink*
# A hospital on the east si
#
# OUTPUT
# like you deserves a major discount! *wink*
# A hospital on the east sid
#
#
# EXAMPLE
#
# INPUT
# e of Shinjuku is closely linked to their plan
# A human guy was here, t
#
# OUTPUT
#  of Shinjuku is closely linked to their plan
# A human guy was here, to
#
#
# EXAMPLE
#
# INPUT
# o.
# A human kid came in and began living here not too long ago.
# A hum
#
# OUTPUT
# .
# A human kid came in and began living here not too long ago.
# A huma
#
#
# EXAMPLE
#
# INPUT
# n's soul can learn, but his body is mortal. A demon is immortal, but h
#
# OUTPUT
# 's soul can learn, but his body is mortal. A demon is immortal, but hi
#
#
# EXAMPLE
#
# INPUT
# s soul never changes.
# A is at the Mantra's headquarters now.
# A long,
#
# OUTPUT
#  soul never changes.
# A is at the Mantra's headquarters now.
# A long,
#
#
# EXAMPLE
#
# INPUT
# long time ago I was summoned by a human, and we talked of many things.
#
# OUTPUT
# ong time ago I was summoned by a human, and we talked of many things.
#
#
# EXAMPLE
#
# INPUT
#
# A lot has happened here, but now it's finally quiet.
# A lot of my fri
#
# OUTPUT
# A lot has happened here, but now it's finally quiet.
# A lot of my frie
#
#
# EXAMPLE
#
# INPUT
# nds are being drained right now.
# A lot of souls have been gathering i
#
# OUTPUT
# ds are being drained right now.
# A lot of souls have been gathering in
#
#
# EXAMPLE
#
# INPUT
#  the Labyrinth.
# A lurks in the room ahead.
# A magazine said that the
#
# OUTPUT
# the Labyrinth.
# A lurks in the room ahead.
# A magazine said that the c
#
#
# EXAMPLE
#
# INPUT
# onflict between the Gaea and Messiah cults is a war between gods and d
#
# OUTPUT
# nflict between the Gaea and Messiah cults is a war between gods and de
#
#
# EXAMPLE
#
# INPUT
# mons.
# A malevolent device, fitting of the Moirae Sisters.
# A man in r
#
# OUTPUT
# ons.
# A malevolent device, fitting of the Moirae Sisters.
# A man in re
#
#
# EXAMPLE
#
# INPUT
# d was looking around here for someone.
# A man who envisions a world of
#
# OUTPUT
#  was looking around here for someone.
# A man who envisions a world of
#
#
# EXAMPLE
#
# INPUT
# silence Ahriman, god of the void, lends him strength.
# A man's greed i
#
# OUTPUT
# ilence Ahriman, god of the void, lends him strength.
# A man's greed is
#
#
# EXAMPLE
#
# INPUT
#  like fire. While it is small, it is warm and comfortable.
# A mere coi
#
# OUTPUT
# like fire. While it is small, it is warm and comfortable.
# A mere coin
#
#
# EXAMPLE
#
# INPUT
# cidence, or the hand of fate? With the Scripture in his possession, he
#
# OUTPUT
# idence, or the hand of fate? With the Scripture in his possession, he
#
#
# EXAMPLE
#
# INPUT
# obtained the Wheel of Amala.
# A mere girl on a power trip A self-indul
#
# OUTPUT
# btained the Wheel of Amala.
# A mere girl on a power trip A self-indulg
#
#
# EXAMPLE
#
# INPUT
# ent brat They can't handle creation!
# A new demon of darkness has been
#
# OUTPUT
# nt brat They can't handle creation!
# A new demon of darkness has been
#
#
# EXAMPLE
#
# INPUT
# born.
# A new world shall be created, no matter which Reason prevails '
#
# OUTPUT
# orn.
# A new world shall be created, no matter which Reason prevails 'T
#
#
# EXAMPLE
#
# INPUT
# is a joyous occasion!
# A painless world because emotions do not contro
#
# OUTPUT
# s a joyous occasion!
# A painless world because emotions do not control
#
#
# EXAMPLE
#
# INPUT
#  it.
# A puny wimp like you won't be able to get in.
# A riot broke out
#
# OUTPUT
# it.
# A puny wimp like you won't be able to get in.
# A riot broke out y
#
#
# EXAMPLE
#
# INPUT
# esterday at Yoyogi Park, regarding the construction of a communication
#
# OUTPUT
# sterday at Yoyogi Park, regarding the construction of a communications
#
#
# EXAMPLE
#
# INPUT
#  tower.
# A seems to have been raised.
# A short while back, a human cam
#
# OUTPUT
# tower.
# A seems to have been raised.
# A short while back, a human came
#
#
# EXAMPLE
#
# INPUT
#  along. He was young.
# A smooth talker like that would be popular with
#
# OUTPUT
# along. He was young.
# A smooth talker like that would be popular with
#
#
# EXAMPLE
#
# INPUT
# the ladies!
# A stone such as this can cast a shadow on my arcane art
#
#
# OUTPUT
# he ladies!
# A stone such as this can cast a shadow on my arcane art
# A
#
#
# EXAMPLE
#
# INPUT
#  strong presence can be felt from behind the door.
# A task as endless
#
# OUTPUT
# strong presence can be felt from behind the door.
# A task as endless a
#
#
# EXAMPLE
#
# INPUT
# s scooping water out of the sea with a cup He was condemned to wander
#
# OUTPUT
#  scooping water out of the sea with a cup He was condemned to wander t
#
#
# EXAMPLE
#
# INPUT
# he infinite span of time.
# A tower coming from Kagutsuchi, the Obelisk
#
# OUTPUT
# e infinite span of time.
# A tower coming from Kagutsuchi, the Obelisk
#
#
# EXAMPLE
#
# INPUT
# shrinking It's all weird.
# A turtle walks up to you.
# A vicious-lookin
#
# OUTPUT
# hrinking It's all weird.
# A turtle walks up to you.
# A vicious-looking
#
#
# EXAMPLE
#
# INPUT
#  Manikin passed by a short while back.
# A vicious-looking Manikin walk
#
# OUTPUT
# Manikin passed by a short while back.
# A vicious-looking Manikin walke
#
#
# EXAMPLE
#
# INPUT
# d into the construction site.
# A voice echoes in your head
# A voice ec
#
# OUTPUT
#  into the construction site.
# A voice echoes in your head
# A voice ech
#
#
# EXAMPLE
#
# INPUT
# oes through the hall
# A voice rings out of nowhere
# A woman you know w
#
# OUTPUT
# es through the hall
# A voice rings out of nowhere
# A woman you know we
#
#
# EXAMPLE
#
# INPUT
# ll prayed to a god in hopes of saving the world
# A world full of peach
#
# OUTPUT
# l prayed to a god in hopes of saving the world
# A world full of peachy
#
#
# EXAMPLE
#
# INPUT
#  Manikins
# A world that loses its power will fade away into nothingnes
#
# OUTPUT
# Manikins
# A world that loses its power will fade away into nothingness
#
#
# EXAMPLE
#
# INPUT
# .
# A world without hierarchy, where everyone lives equally in peace *c
#
# OUTPUT
#
# A world without hierarchy, where everyone lives equally in peace *ch
#
#
# EXAMPLE
#
# INPUT
# uckle*
# A young man yearning to live in solitude His strength comes fr
#
# OUTPUT
# ckle*
# A young man yearning to live in solitude His strength comes fro
#
#
# EXAMPLE
#
# INPUT
# m Noah, the wandering god.
# A young woman who values power above all e
#
# OUTPUT
#  Noah, the wandering god.
# A young woman who values power above all el
#
#
# EXAMPLE
#
# INPUT
# se The god Baal Avatar has descended upon her.
# ALRIGHT, I WILL HELP Y
#
# OUTPUT
# e The god Baal Avatar has descended upon her.
# ALRIGHT, I WILL HELP YO
#
#
# EXAMPLE
#
# INPUT
# U CREATE THE WORLD!
# About negotiating Well, I dunno all the details,
#
# OUTPUT
#  CREATE THE WORLD!
# About negotiating Well, I dunno all the details, s
#
#
# EXAMPLE
#
# INPUT
# o I can't tell you anything specific.
# About the Nightmare System I've
#
# OUTPUT
#  I can't tell you anything specific.
# About the Nightmare System I've
#
#
# EXAMPLE
#
# INPUT
# got good news.
# About the old Manikin that was here
# Above He's on the
#
# OUTPUT
# ot good news.
# About the old Manikin that was here
# Above He's on the
#
#
# EXAMPLE
#
# INPUT
# 5th floor
# According to our comrades, there's a bunch of traps on the
#
# OUTPUT
# th floor
# According to our comrades, there's a bunch of traps on the f
#
#
# EXAMPLE
#
# INPUT
# loors above.
# According to the report, there's a group of demon worshi
#
# OUTPUT
# oors above.
# According to the report, there's a group of demon worship
#
#
# EXAMPLE
#
# INPUT
# pers who call themselves the Gaea cult
# Acquire ten of them for a raff
#
# OUTPUT
# ers who call themselves the Gaea cult
# Acquire ten of them for a raffl
#
#
# EXAMPLE
#
# INPUT
# e. You can also use them in any of the Junk Shops.
# Actually, humans c
#
# OUTPUT
# . You can also use them in any of the Junk Shops.
# Actually, humans ca
#
#
# EXAMPLE
#
# INPUT
# n be crueler than you think, even crueler than demons
# Add Candelabrum
#
# OUTPUT
#  be crueler than you think, even crueler than demons
# Add Candelabrum
#
#
# EXAMPLE
#
# INPUT
# of Foundation to inventory?
# Add Candelabrum of Sovereignty to invento
#
# OUTPUT
# f Foundation to inventory?
# Add Candelabrum of Sovereignty to inventor
#
#
# EXAMPLE
#
# INPUT
# y?
# Add which candelabrum to your inventory?
# After all, only you can
#
# OUTPUT
# ?
# Add which candelabrum to your inventory?
# After all, only you can b
#
#
# EXAMPLE
#
# INPUT
# e at the center of your world, right?
# After climbing steep paths, fal
#
# OUTPUT
#  at the center of your world, right?
# After climbing steep paths, fall
#
#
# EXAMPLE
#
# INPUT
# ing, scraping knees, finally
# After that, a female human passed by.
# A
#
# OUTPUT
# ng, scraping knees, finally
# After that, a female human passed by.
# Af
#
#
# EXAMPLE
#
# INPUT
# ter the incident, we've had a lot of lookee-loos, but not so many cust
#
# OUTPUT
# er the incident, we've had a lot of lookee-loos, but not so many custo
#
#
# EXAMPLE
#
# INPUT
# mers.
# After this event, the world will become a Vortex.
# After we fin
#
# OUTPUT
# ers.
# After this event, the world will become a Vortex.
# After we fini
#
#
# EXAMPLE
#
# INPUT
# sh off the mud puppets, Lady 's god shall descend upon us.
# After we w
#
# OUTPUT
# h off the mud puppets, Lady 's god shall descend upon us.
# After we we
#
#
# EXAMPLE
#
# INPUT
# nt our separate ways, I started thinking.
# After years a pokin' around
#
# OUTPUT
# t our separate ways, I started thinking.
# After years a pokin' around,
#
#
# EXAMPLE
#
# INPUT
#  I finally located the treasure right here! But
# After you went inside
#
# OUTPUT
# I finally located the treasure right here! But
# After you went inside,
#
#
# EXAMPLE
#
# INPUT
#  the sky lit right up. It was like magic!
# Ah Don't Don't talk to me!
#
# OUTPUT
# the sky lit right up. It was like magic!
# Ah Don't Don't talk to me!
#
#
#
# EXAMPLE
#
# INPUT
# Ah! But, now you're a demon!
# Ah, I have committed murder once again.
#
# OUTPUT
# h! But, now you're a demon!
# Ah, I have committed murder once again.
#
#
#
# EXAMPLE
#
# INPUT
# Ah, it has such a sweet ring to it.
# Ah, whatever Pixies, deal with hi
#
# OUTPUT
# h, it has such a sweet ring to it.
# Ah, whatever Pixies, deal with him
#
#
# EXAMPLE
#
# INPUT
# !
# Ahaha If you want her back, you must defeat us.
# Ahaha Were you abl
#
# OUTPUT
#
# Ahaha If you want her back, you must defeat us.
# Ahaha Were you able
#
#
# EXAMPLE
#
# INPUT
#  to keep up with Kagutsuchi?
# All I see is darkness inside you
# All I
#
# OUTPUT
# to keep up with Kagutsuchi?
# All I see is darkness inside you
# All I w
#
#
# EXAMPLE
#
# INPUT
# anted was to be like the legendary King! Scary, yet cute
# All of a sud
#
# OUTPUT
# nted was to be like the legendary King! Scary, yet cute
# All of a sudd
#
#
# EXAMPLE
#
# INPUT
# en, I was blinded by a bright light, and the next thing I knew, I was
#
# OUTPUT
# n, I was blinded by a bright light, and the next thing I knew, I was h
#
#
# EXAMPLE
#
# INPUT
# ere in this room.
# All of the candelabra have been lit
# All of the dem
#
# OUTPUT
# re in this room.
# All of the candelabra have been lit
# All of the demo
#
#
# EXAMPLE
#
# INPUT
# ns are celebrating the birth of the new demon of darkness,
# All of the
#
# OUTPUT
# s are celebrating the birth of the new demon of darkness,
# All of the
#
#
# EXAMPLE
#
# INPUT
# humans are gone, though.
# All of the power that lay dormant inside you
#
# OUTPUT
# umans are gone, though.
# All of the power that lay dormant inside you
#
#
# EXAMPLE
#
# INPUT
# has now been unleashed.
# All of you who have lurked in darkness and wa
#
# OUTPUT
# as now been unleashed.
# All of you who have lurked in darkness and wai
#
#
# EXAMPLE
#
# INPUT
# ted faithfully for this day, hear me
# All possibility has dried up in
#
# OUTPUT
# ed faithfully for this day, hear me
# All possibility has dried up in t
#
#
# EXAMPLE
#
# INPUT
# his world
# All that's left is to finish off that arrogant mud puppet,
#
# OUTPUT
# is world
# All that's left is to finish off that arrogant mud puppet, F
#
#
# EXAMPLE
#
# INPUT
# utomimi
# All the Magatsuhi from the Amala Network comes from here.
# Al
#
# OUTPUT
# tomimi
# All the Magatsuhi from the Amala Network comes from here.
# All
#
#
# EXAMPLE
#
# INPUT
#  the Magatsuhi is mine! That's what he yells all the time.
# All the Ma
#
# OUTPUT
# the Magatsuhi is mine! That's what he yells all the time.
# All the Man
#
#
# EXAMPLE
#
# INPUT
# tra demons are there. May their souls rest in peace
# All the inhabitan
#
# OUTPUT
# ra demons are there. May their souls rest in peace
# All the inhabitant
#
#
# EXAMPLE
#
# INPUT
# s of this world will follow before long.
# All the members of Mantra ar
#
# OUTPUT
#  of this world will follow before long.
# All the members of Mantra are
#
#
# EXAMPLE
#
# INPUT
#  being drained of their Magatsuhi!
# All the pillars have been lowered.
#
# OUTPUT
# being drained of their Magatsuhi!
# All the pillars have been lowered.
#
#
# EXAMPLE
#
# INPUT
#
# All the torture must have gotten to him. He doesn't want to move.
# Al
#
# OUTPUT
# All the torture must have gotten to him. He doesn't want to move.
# All
#
#
# EXAMPLE
#
# INPUT
#  things have a front and a back, and only by knowing both sides can yo
#
# OUTPUT
# things have a front and a back, and only by knowing both sides can you
#
#
# EXAMPLE
#
# INPUT
#  fully understand them.
# All this time, you've just been running away
#
# OUTPUT
# fully understand them.
# All this time, you've just been running away t
#
#
# EXAMPLE
#
# INPUT
# rying to leave everything behind.
# All we can do is hide and tremble i
#
# OUTPUT
# ying to leave everything behind.
# All we can do is hide and tremble in
#
#
# EXAMPLE
#
# INPUT
#  fear!
# All we have to do now is summon our god, and we will receive t
#
# OUTPUT
# fear!
# All we have to do now is summon our god, and we will receive th
#
#
# EXAMPLE
#
# INPUT
# e Reason of Shijima!
# Allow me to give you this.
# Allow me to judge yo
#
# OUTPUT
#  Reason of Shijima!
# Allow me to give you this.
# Allow me to judge you
#
#
# EXAMPLE
#
# INPUT
# r power!!
# Allow me to tell you one thing, if you don't mind
# Alright
#
# OUTPUT
#  power!!
# Allow me to tell you one thing, if you don't mind
# Alright L
#
#
# EXAMPLE
#
# INPUT
# et's do it this way.
# Alright then, let's get outta here!
# Alright! I'
#
# OUTPUT
# t's do it this way.
# Alright then, let's get outta here!
# Alright! I'l
#
#
# EXAMPLE
#
# INPUT
# l help you get through, nice and easy!
# Alright! This time, let's try
#
# OUTPUT
#  help you get through, nice and easy!
# Alright! This time, let's try t
#
#
# EXAMPLE
#
# INPUT
# he cross-formation!
# Alright! You know how to make things fun!
# Alrigh
#
# OUTPUT
# e cross-formation!
# Alright! You know how to make things fun!
# Alright
#
#
# EXAMPLE
#
# INPUT
# , I'll do the best I can to get you outta there.
# Alright, I'll persua
#
# OUTPUT
#  I'll do the best I can to get you outta there.
# Alright, I'll persuad
#
#
# EXAMPLE
#
# INPUT
# e the gatekeeper to let you through.
# Alright, I'll tell you something
#
# OUTPUT
#  the gatekeeper to let you through.
# Alright, I'll tell you something
#
#
# EXAMPLE
#
# INPUT
# you might wanna know
# Alright, I'm gonna count to three. That's how lo
#
# OUTPUT
# ou might wanna know
# Alright, I'm gonna count to three. That's how lon
#
#
# EXAMPLE
#
# INPUT
# g you've got to come up with a plan.
# Alright, keep it up. I'll just k
#
# OUTPUT
#  you've got to come up with a plan.
# Alright, keep it up. I'll just ki
#
#
# EXAMPLE
#
# INPUT
# ck back.
# Alright, let me try something. Gimme a minute.
# Alright, let
#
# OUTPUT
# k back.
# Alright, let me try something. Gimme a minute.
# Alright, let'
#
#
# EXAMPLE
#
# INPUT
# s continue. It was about your opponent, right?
# Alright, one more. Pic
#
# OUTPUT
#  continue. It was about your opponent, right?
# Alright, one more. Pick
#
#
# EXAMPLE
#
# INPUT
#  any one that ya like.
# Alright, they fell for it! You ready?
# Alright
#
# OUTPUT
# any one that ya like.
# Alright, they fell for it! You ready?
# Alrighty
#
#
# EXAMPLE
#
# INPUT
# ! I guess I'll stay with you a little longer!
# Also, , the top executi
#
# OUTPUT
#  I guess I'll stay with you a little longer!
# Also, , the top executiv
#
#
# EXAMPLE
#
# INPUT
# e of Cybers Communication, is still missing.
# Also, accidents often oc
#
# OUTPUT
#  of Cybers Communication, is still missing.
# Also, accidents often occ
#
#
# EXAMPLE
#
# INPUT
# ur when Kagutsuchi is at its brightest.
# Also, if you level up a demon
#
# OUTPUT
# r when Kagutsuchi is at its brightest.
# Also, if you level up a demon
#
#
# EXAMPLE
#
# INPUT
# and register it, you will be able to summon it at that level.
# Also, i
#
# OUTPUT
# nd register it, you will be able to summon it at that level.
# Also, in
#
#
# EXAMPLE
#
# INPUT
#  some cases, you may end up with a completely different demon than you
#
# OUTPUT
# some cases, you may end up with a completely different demon than you
#
#
# EXAMPLE
#
# INPUT
# expected.
# Although, I believe your destiny is to fight alongside us.
#
# OUTPUT
# xpected.
# Although, I believe your destiny is to fight alongside us.
#
#
#
# EXAMPLE
#
# INPUT
# Am I that peculiar? Have you been living all your demon life in a cave
#
# OUTPUT
# m I that peculiar? Have you been living all your demon life in a cave?
#
#
# EXAMPLE
#
# INPUT
#
# Amala Network: Medical Center 5F sub-terminal
# Amala Network: Medica
#
# OUTPUT
#
# Amala Network: Medical Center 5F sub-terminal
# Amala Network: Medical
#
#
# EXAMPLE
#
# INPUT
#  Center main terminal
# An intruder got this far? I hope Commander Hika
#
# OUTPUT
# Center main terminal
# An intruder got this far? I hope Commander Hikaw
#
#
# EXAMPLE
#
# INPUT
# a isn't slipping!
# And 4 of 'em, on top of that.
# And I alone will car
#
# OUTPUT
#  isn't slipping!
# And 4 of 'em, on top of that.
# And I alone will carr
#
#
# EXAMPLE
#
# INPUT
# y the burden of its sin.
# And I am not the only one!
# And I don't know
#
# OUTPUT
#  the burden of its sin.
# And I am not the only one!
# And I don't know
# EXAMPLE
#
# INPUT
# what it's gonna be like when it does get reborn
# And I mean, mop the f
#
# OUTPUT
# hat it's gonna be like when it does get reborn
# And I mean, mop the fl
#
#
# EXAMPLE
#
# INPUT
# oor!!
# And I opened the way without anybody's help.
# And I was right L
#
# OUTPUT
# or!!
# And I opened the way without anybody's help.
# And I was right Lo
#
#
# EXAMPLE
#
# INPUT
# oks like I hit the jackpot.
# And Kagutsuchi, the light that watches ov
#
# OUTPUT
# ks like I hit the jackpot.
# And Kagutsuchi, the light that watches ove
#
#
# EXAMPLE
#
# INPUT
# r the Vortex World as well as creation
# And all those that we called c
#
# OUTPUT
#  the Vortex World as well as creation
# And all those that we called co
#
#
# EXAMPLE
#
# INPUT
# mrades have deserted us.
# And by deciphering the symbols on it,
# And h
#
# OUTPUT
# rades have deserted us.
# And by deciphering the symbols on it,
# And he
#
#
# EXAMPLE
#
# INPUT
# 's got lots of it, that's for sure.
# And here I was wondering what kin
#
# OUTPUT
# s got lots of it, that's for sure.
# And here I was wondering what kind
#
#
# EXAMPLE
#
# INPUT
#  of demon was trespassing Why, you're only a harmless child!
# And if y
#
# OUTPUT
# of demon was trespassing Why, you're only a harmless child!
# And if yo
#
#
# EXAMPLE
#
# INPUT
# u call I will rise from the depths of hell to assist you
# And if you t
#
# OUTPUT
#  call I will rise from the depths of hell to assist you
# And if you tr
#
#
# EXAMPLE
#
# INPUT
# y to force your way through, you'll run into even more trouble!
# And i
#
# OUTPUT
#  to force your way through, you'll run into even more trouble!
# And it
#
#
# EXAMPLE
#
# INPUT
#  is your fate that you will live through the Conception.
# And judging
#
# OUTPUT
# is your fate that you will live through the Conception.
# And judging b
#
#
# EXAMPLE
#
# INPUT
# y your appearance you've gained considerable power.
# And lastly, there
#
# OUTPUT
#  your appearance you've gained considerable power.
# And lastly, there'
#
#
# EXAMPLE
#
# INPUT
# s a fire demon. Make sure to use to win.
# And most likely that network
#
# OUTPUT
#  a fire demon. Make sure to use to win.
# And most likely that network
#
#
# EXAMPLE
#
# INPUT
# is connected to where Hikawa is.
# And not just that An entire legion o
#
# OUTPUT
# s connected to where Hikawa is.
# And not just that An entire legion of
#
#
# EXAMPLE
#
# INPUT
#  my best troops awaits you!
# And now, over to Kei for the latest in sp
#
# OUTPUT
# my best troops awaits you!
# And now, over to Kei for the latest in spo
#
#
# EXAMPLE
#
# INPUT
# rts!
# And now, time has met her death.
# And now, you have been born a
#
# OUTPUT
# ts!
# And now, time has met her death.
# And now, you have been born a s
#
#
# EXAMPLE
#
# INPUT
# econd time
# And that's where Hikawa will be.
# And the other one looks
#
# OUTPUT
# cond time
# And that's where Hikawa will be.
# And the other one looks l
#
#
# EXAMPLE
#
# INPUT
# ike a cross.
# And the reason he was able to make his plot a reality
# A
#
# OUTPUT
# ke a cross.
# And the reason he was able to make his plot a reality
# An
#
#
# EXAMPLE
#
# INPUT
# d the war still rages on, even as we speak.
# And those lights on the b
#
# OUTPUT
#  the war still rages on, even as we speak.
# And those lights on the br
#
#
# EXAMPLE
#
# INPUT
# idges are Pixies.
# And ultimately, he reached beyond the scope of mank
#
# OUTPUT
# dges are Pixies.
# And ultimately, he reached beyond the scope of manki
#
#
# EXAMPLE
#
# INPUT
# nd and plotted the creation of the world.
# And when his wish comes tru
#
# OUTPUT
# d and plotted the creation of the world.
# And when his wish comes true
#
#
# EXAMPLE
#
# INPUT
#
# And you are the one who will accomplish that.
# And you weren't attac
#
# OUTPUT
#
# And you are the one who will accomplish that.
# And you weren't attack
#
#
# EXAMPLE
#
# INPUT
# ed by oni???
# And, I clean up after them
# And, you shall eventually jo
#
# OUTPUT
# d by oni???
# And, I clean up after them
# And, you shall eventually joi
#
#
# EXAMPLE
#
# INPUT
# n him in the afterlife Now, let us pray.
# Any who enter the territory
#
# OUTPUT
#  him in the afterlife Now, let us pray.
# Any who enter the territory o
#
#
# EXAMPLE
#
# INPUT
# f the Mantra will be tried.
# Anybody would assume that this is the cor
#
# OUTPUT
#  the Mantra will be tried.
# Anybody would assume that this is the core
#
#
# EXAMPLE
#
# INPUT
#  of Nihilo.
# Anything is possible in the vast ocean of Amala.
# Anyway,
#
# OUTPUT
# of Nihilo.
# Anything is possible in the vast ocean of Amala.
# Anyway,
#
#
# EXAMPLE
#
# INPUT
# don't keep us waiting, okay?
# Anyway, let's report this to everyone!
#
#
# OUTPUT
# on't keep us waiting, okay?
# Anyway, let's report this to everyone!
# A
#
#
# EXAMPLE
#
# INPUT
# nyway, once again I'm aiming to be the best!
# Anyway, they believe in
#
# OUTPUT
# yway, once again I'm aiming to be the best!
# Anyway, they believe in t
#
#
# EXAMPLE
#
# INPUT
# his book of prophecy called the Scripture of Miroku.
# Anyways I entrus
#
# OUTPUT
# is book of prophecy called the Scripture of Miroku.
# Anyways I entrust
#
#
# EXAMPLE
#
# INPUT
#  you with finding that Bill.
# Anyways, I'm glad to see that you're oka
#
# OUTPUT
# you with finding that Bill.
# Anyways, I'm glad to see that you're okay
#
#
# EXAMPLE
#
# INPUT
# .
# Anyways, like I suspected, the terminal here isn't under Nihilo's s
#
# OUTPUT
#
# Anyways, like I suspected, the terminal here isn't under Nihilo's su
#
#
# EXAMPLE
#
# INPUT
# rveillance.
# Anyways, this isn't the time for Chiaki! Get someone over
#
# OUTPUT
# veillance.
# Anyways, this isn't the time for Chiaki! Get someone over
#
#
# EXAMPLE
#
# INPUT
# here!
# Apathy is not the answer! We must fight for what we believe in!
#
# OUTPUT
# ere!
# Apathy is not the answer! We must fight for what we believe in!!

# %%
#text to left
for x, y in dataset_left.take(147):
  print("\n\nEXAMPLE\n")
  print("INPUT")
  print(int_to_text(x))
  print("\nOUTPUT")
  print(int_to_text(y))
# Out:
# EXAMPLE
#
# INPUT
# oV eht ot gninruter fo sepoh ni ,delf dna ti nelots evah tsum nikinaM
#
# OUTPUT
# V eht ot gninruter fo sepoh ni ,delf dna ti nelots evah tsum nikinaM A
#
#
# EXAMPLE
#
# INPUT
# rtnaM fo hcnub A
#  .sriatsnwod tnew snikinaM fo puorg gib A
#  .dlroW xet
#
# OUTPUT
# tnaM fo hcnub A
#  .sriatsnwod tnew snikinaM fo puorg gib A
#  .dlroW xetr
#
#
# EXAMPLE
#
# INPUT
# inaM ahcnub A
#  .olihiN thgif ot yaw rieht no ereh hguorht emac snomed
#
# OUTPUT
# naM ahcnub A
#  .olihiN thgif ot yaw rieht no ereh hguorht emac snomed a
#
#
# EXAMPLE
#
# INPUT
# luoc uoY .dellik erew elpoep ahcnub A
#  !ereht ni thgir deklaw tsuj sni
#
# OUTPUT
# uoc uoY .dellik erew elpoep ahcnub A
#  !ereht ni thgir deklaw tsuj snik
#
#
# EXAMPLE
#
# INPUT
# trats ot tuoba si ynomerec A
#  .gnol thgin lla gniliaw sneris eht raeh
#
# OUTPUT
# rats ot tuoba si ynomerec A
#  .gnol thgin lla gniliaw sneris eht raeh d
#
#
# EXAMPLE
#
# INPUT
# if smees tI .deraperp gnieb si ynomerec A
#  deedni yhsif yrev smees tI
#
# OUTPUT
# f smees tI .deraperp gnieb si ynomerec A
#  deedni yhsif yrev smees tI .
#
#
# EXAMPLE
#
# INPUT
# it fo sgnikrow eht htiw ynomrah ni ,ssenllits fo elcric etelpmoc A
#  yh
#
# OUTPUT
# t fo sgnikrow eht htiw ynomrah ni ,ssenllits fo elcric etelpmoc A
#  yhs
#
#
# EXAMPLE
#
# INPUT
# M gnikcatta si lrig nomed A
#  dlrow eht rof egnahcxe ni nrob nomed A
#  e
#
# OUTPUT
#  gnikcatta si lrig nomed A
#  dlrow eht rof egnahcxe ni nrob nomed A
#  em
#
#
# EXAMPLE
#
# INPUT
#  ,esac sih now tsuj nomed A
#  reyals nomed a gnirih nomed A
#  !orihsanuf
#
# OUTPUT
# ,esac sih now tsuj nomed A
#  reyals nomed a gnirih nomed A
#  !orihsanufi
#
#
# EXAMPLE
#
# INPUT
#  eht htiw nomed A
#  . ot em ekat pleh nac ohw nomed A
#  .eerf tes saw dn
#
# OUTPUT
# eht htiw nomed A
#  . ot em ekat pleh nac ohw nomed A
#  .eerf tes saw dna
#
#
# EXAMPLE
#
# INPUT
# ets ot emac lrig ekil-nomed A
#  soahc fo noipmahc eht emoceb ot htgnert
#
# OUTPUT
# ts ot emac lrig ekil-nomed A
#  soahc fo noipmahc eht emoceb ot htgnerts
#
#
# EXAMPLE
#
# INPUT
# ereh ,oS .selur eht wonk t'nod uoy fi nuf on s'emag A
#  ihustagaM ruo l
#
# OUTPUT
# reh ,oS .selur eht wonk t'nod uoy fi nuf on s'emag A
#  ihustagaM ruo la
#
#
# EXAMPLE
#
# INPUT
# ecil neve s'eh kniht t'nod I !!elcycrotom a gnidir tsohg A
#  laed eht s
#
# OUTPUT
# cil neve s'eh kniht t'nod I !!elcycrotom a gnidir tsohg A
#  laed eht s'
#
#
# EXAMPLE
#
# INPUT
#  dlrow citoahc siht egnahc ot gniog si lliw gnorts a htiw yug A
#  !!des
#
# OUTPUT
# dlrow citoahc siht egnahc ot gniog si lliw gnorts a htiw yug A
#  !!desn
#
#
# EXAMPLE
#
# INPUT
# nomed emosdnah A
#  !tnuocsid rojam a sevresed uoy ekil nomed emosdnah A
#
# OUTPUT
# omed emosdnah A
#  !tnuocsid rojam a sevresed uoy ekil nomed emosdnah A
#
#
#
# EXAMPLE
#
# INPUT
# dis tsae eht no latipsoh A
#  *kniw* !tnuocsid rojam a sevresed uoy ekil
#
# OUTPUT
# is tsae eht no latipsoh A
#  *kniw* !tnuocsid rojam a sevresed uoy ekil
#
#
# EXAMPLE
#
# INPUT
# ot ,ereh saw yug namuh A
#  nalp rieht ot deknil ylesolc si ukujnihS fo
#
# OUTPUT
# t ,ereh saw yug namuh A
#  nalp rieht ot deknil ylesolc si ukujnihS fo e
#
#
# EXAMPLE
#
# INPUT
# amuh A
#  .oga gnol oot ton ereh gnivil nageb dna ni emac dik namuh A
#  .
#
# OUTPUT
# muh A
#  .oga gnol oot ton ereh gnivil nageb dna ni emac dik namuh A
#  .o
#
#
# EXAMPLE
#
# INPUT
# ih tub ,latrommi si nomed A .latrom si ydob sih tub ,nrael nac luos s'
#
# OUTPUT
# h tub ,latrommi si nomed A .latrom si ydob sih tub ,nrael nac luos s'n
#
#
# EXAMPLE
#
# INPUT
#  ,gnol A
#  .won sretrauqdaeh s'artnaM eht ta si A
#  .segnahc reven luos
#
# OUTPUT
# ,gnol A
#  .won sretrauqdaeh s'artnaM eht ta si A
#  .segnahc reven luos s
#
#
# EXAMPLE
#
# INPUT
#  .sgniht ynam fo deklat ew dna ,namuh a yb denommus saw I oga emit gno
#
# OUTPUT
# .sgniht ynam fo deklat ew dna ,namuh a yb denommus saw I oga emit gnol
#
#
# EXAMPLE
#
# INPUT
# eirf ym fo tol A
#  .teiuq yllanif s'ti won tub ,ereh deneppah sah tol A
#
# OUTPUT
# irf ym fo tol A
#  .teiuq yllanif s'ti won tub ,ereh deneppah sah tol A
#
#
#
# EXAMPLE
#
# INPUT
# ni gnirehtag neeb evah sluos fo tol A
#  .won thgir deniard gnieb era sd
#
# OUTPUT
# i gnirehtag neeb evah sluos fo tol A
#  .won thgir deniard gnieb era sdn
#
#
# EXAMPLE
#
# INPUT
# c eht taht dias enizagam A
#  .daeha moor eht ni skrul A
#  .htnirybaL eht
#
# OUTPUT
#  eht taht dias enizagam A
#  .daeha moor eht ni skrul A
#  .htnirybaL eht
#
#
# EXAMPLE
#
# INPUT
# ed dna sdog neewteb raw a si stluc haisseM dna aeaG eht neewteb tcilfn
#
# OUTPUT
# d dna sdog neewteb raw a si stluc haisseM dna aeaG eht neewteb tcilfno
#
#
# EXAMPLE
#
# INPUT
# er ni nam A
#  .sretsiS earioM eht fo gnittif ,ecived tnelovelam A
#  .sno
#
# OUTPUT
# r ni nam A
#  .sretsiS earioM eht fo gnittif ,ecived tnelovelam A
#  .snom
#
#
# EXAMPLE
#
# INPUT
#  fo dlrow a snoisivne ohw nam A
#  .enoemos rof ereh dnuora gnikool saw
#
# OUTPUT
# fo dlrow a snoisivne ohw nam A
#  .enoemos rof ereh dnuora gnikool saw d
#
#
# EXAMPLE
#
# INPUT
# si deerg s'nam A
#  .htgnerts mih sdnel ,diov eht fo dog ,namirhA ecneli
#
# OUTPUT
# i deerg s'nam A
#  .htgnerts mih sdnel ,diov eht fo dog ,namirhA ecnelis
#
#
# EXAMPLE
#
# INPUT
# nioc erem A
#  .elbatrofmoc dna mraw si ti ,llams si ti elihW .erif ekil
#
# OUTPUT
# ioc erem A
#  .elbatrofmoc dna mraw si ti ,llams si ti elihW .erif ekil
#
#
# EXAMPLE
#
# INPUT
#  eh ,noissessop sih ni erutpircS eht htiW ?etaf fo dnah eht ro ,ecnedi
#
# OUTPUT
# eh ,noissessop sih ni erutpircS eht htiW ?etaf fo dnah eht ro ,ecnedic
#
#
# EXAMPLE
#
# INPUT
# gludni-fles A pirt rewop a no lrig erem A
#  .alamA fo leehW eht deniatb
#
# OUTPUT
# ludni-fles A pirt rewop a no lrig erem A
#  .alamA fo leehW eht deniatbo
#
#
# EXAMPLE
#
# INPUT
#  neeb sah ssenkrad fo nomed wen A
#  !noitaerc eldnah t'nac yehT tarb tn
#
# OUTPUT
# neeb sah ssenkrad fo nomed wen A
#  !noitaerc eldnah t'nac yehT tarb tne
#
#
# EXAMPLE
#
# INPUT
# T' sliaverp nosaeR hcihw rettam on ,detaerc eb llahs dlrow wen A
#  .nro
#
# OUTPUT
# ' sliaverp nosaeR hcihw rettam on ,detaerc eb llahs dlrow wen A
#  .nrob
#
#
# EXAMPLE
#
# INPUT
# lortnoc ton od snoitome esuaceb dlrow sselniap A
#  !noisacco suoyoj a s
#
# OUTPUT
# ortnoc ton od snoitome esuaceb dlrow sselniap A
#  !noisacco suoyoj a si
#
#
# EXAMPLE
#
# INPUT
# y tuo ekorb toir A
#  .ni teg ot elba eb t'now uoy ekil pmiw ynup A
#  .ti
#
# OUTPUT
#  tuo ekorb toir A
#  .ni teg ot elba eb t'now uoy ekil pmiw ynup A
#  .ti
#
#
# EXAMPLE
#
# INPUT
# snoitacinummoc a fo noitcurtsnoc eht gnidrager ,kraP igoyoY ta yadrets
#
# OUTPUT
# noitacinummoc a fo noitcurtsnoc eht gnidrager ,kraP igoyoY ta yadretse
#
#
# EXAMPLE
#
# INPUT
# emac namuh a ,kcab elihw trohs A
#  .desiar neeb evah ot smees A
#  .rewot
#
# OUTPUT
# mac namuh a ,kcab elihw trohs A
#  .desiar neeb evah ot smees A
#  .rewot
#
#
# EXAMPLE
#
# INPUT
#  htiw ralupop eb dluow taht ekil reklat htooms A
#  .gnuoy saw eH .gnola
#
# OUTPUT
# htiw ralupop eb dluow taht ekil reklat htooms A
#  .gnuoy saw eH .gnola
#
#
# EXAMPLE
#
# INPUT
# A
#  tra enacra ym no wodahs a tsac nac siht sa hcus enots A
#  !seidal eh
#
# OUTPUT
#
#  tra enacra ym no wodahs a tsac nac siht sa hcus enots A
#  !seidal eht
#
#
# EXAMPLE
#
# INPUT
# a sseldne sa ksat A
#  .rood eht dniheb morf tlef eb nac ecneserp gnorts
#
# OUTPUT
#  sseldne sa ksat A
#  .rood eht dniheb morf tlef eb nac ecneserp gnorts
#
#
# EXAMPLE
#
# INPUT
# t rednaw ot denmednoc saw eH puc a htiw aes eht fo tuo retaw gnipoocs
#
# OUTPUT
#  rednaw ot denmednoc saw eH puc a htiw aes eht fo tuo retaw gnipoocs s
#
#
# EXAMPLE
#
# INPUT
#  ksilebO eht ,ihcustugaK morf gnimoc rewot A
#  .emit fo naps etinifni e
#
# OUTPUT
# ksilebO eht ,ihcustugaK morf gnimoc rewot A
#  .emit fo naps etinifni eh
#
#
# EXAMPLE
#
# INPUT
# gnikool-suoiciv A
#  .uoy ot pu sklaw eltrut A
#  .driew lla s'tI gniknirh
#
# OUTPUT
# nikool-suoiciv A
#  .uoy ot pu sklaw eltrut A
#  .driew lla s'tI gniknirhs
#
#
# EXAMPLE
#
# INPUT
# eklaw nikinaM gnikool-suoiciv A
#  .kcab elihw trohs a yb dessap nikinaM
#
# OUTPUT
# klaw nikinaM gnikool-suoiciv A
#  .kcab elihw trohs a yb dessap nikinaM
#
#
# EXAMPLE
#
# INPUT
# hce eciov A
#  daeh ruoy ni seohce eciov A
#  .etis noitcurtsnoc eht otni
#
# OUTPUT
# ce eciov A
#  daeh ruoy ni seohce eciov A
#  .etis noitcurtsnoc eht otni d
#
#
# EXAMPLE
#
# INPUT
# ew wonk uoy namow A
#  erehwon fo tuo sgnir eciov A
#  llah eht hguorht se
#
# OUTPUT
# w wonk uoy namow A
#  erehwon fo tuo sgnir eciov A
#  llah eht hguorht seo
#
#
# EXAMPLE
#
# INPUT
# yhcaep fo lluf dlrow A
#  dlrow eht gnivas fo sepoh ni dog a ot deyarp l
#
# OUTPUT
# hcaep fo lluf dlrow A
#  dlrow eht gnivas fo sepoh ni dog a ot deyarp ll
#
#
# EXAMPLE
#
# INPUT
# ssengnihton otni yawa edaf lliw rewop sti sesol taht dlrow A
#  snikinaM
#
# OUTPUT
# sengnihton otni yawa edaf lliw rewop sti sesol taht dlrow A
#  snikinaM
#
#
# EXAMPLE
#
# INPUT
# hc* ecaep ni yllauqe sevil enoyreve erehw ,yhcrareih tuohtiw dlrow A
#
#
# OUTPUT
# c* ecaep ni yllauqe sevil enoyreve erehw ,yhcrareih tuohtiw dlrow A
#  .
#
#
# EXAMPLE
#
# INPUT
# orf semoc htgnerts siH edutilos ni evil ot gninraey nam gnuoy A
#  *elkc
#
# OUTPUT
# rf semoc htgnerts siH edutilos ni evil ot gninraey nam gnuoy A
#  *elkcu
#
#
# EXAMPLE
#
# INPUT
# le lla evoba rewop seulav ohw namow gnuoy A
#  .dog gnirednaw eht ,haoN
#
# OUTPUT
# e lla evoba rewop seulav ohw namow gnuoy A
#  .dog gnirednaw eht ,haoN m
#
#
# EXAMPLE
#
# INPUT
# OY PLEH LLIW I ,THGIRLA
#  .reh nopu dednecsed sah ratavA laaB dog ehT e
#
# OUTPUT
# Y PLEH LLIW I ,THGIRLA
#  .reh nopu dednecsed sah ratavA laaB dog ehT es
#
#
# EXAMPLE
#
# INPUT
# s ,sliated eht lla onnud I ,lleW gnitaitogen tuobA
#  !DLROW EHT ETAERC
#
# OUTPUT
#  ,sliated eht lla onnud I ,lleW gnitaitogen tuobA
#  !DLROW EHT ETAERC U
#
#
# EXAMPLE
#
# INPUT
#  ev'I metsyS eramthgiN eht tuobA
#  .cificeps gnihtyna uoy llet t'nac I
#
# OUTPUT
# ev'I metsyS eramthgiN eht tuobA
#  .cificeps gnihtyna uoy llet t'nac I o
#
#
# EXAMPLE
#
# INPUT
#  eht no s'eH evobA
#  ereh saw taht nikinaM dlo eht tuobA
#  .swen doog to
#
# OUTPUT
# eht no s'eH evobA
#  ereh saw taht nikinaM dlo eht tuobA
#  .swen doog tog
#
#
# EXAMPLE
#
# INPUT
# f eht no spart fo hcnub a s'ereht ,sedarmoc ruo ot gnidroccA
#  roolf ht
#
# OUTPUT
#  eht no spart fo hcnub a s'ereht ,sedarmoc ruo ot gnidroccA
#  roolf ht5
#
#
# EXAMPLE
#
# INPUT
# pihsrow nomed fo puorg a s'ereht ,troper eht ot gnidroccA
#  .evoba sroo
#
# OUTPUT
# ihsrow nomed fo puorg a s'ereht ,troper eht ot gnidroccA
#  .evoba srool
#
#
# EXAMPLE
#
# INPUT
# lffar a rof meht fo net eriuqcA
#  tluc aeaG eht sevlesmeht llac ohw sre
#
# OUTPUT
# ffar a rof meht fo net eriuqcA
#  tluc aeaG eht sevlesmeht llac ohw srep
#
#
# EXAMPLE
#
# INPUT
# ac snamuh ,yllautcA
#  .spohS knuJ eht fo yna ni meht esu osla nac uoY .
#
# OUTPUT
# c snamuh ,yllautcA
#  .spohS knuJ eht fo yna ni meht esu osla nac uoY .e
#
#
# EXAMPLE
#
# INPUT
#  murbalednaC ddA
#  snomed naht releurc neve ,kniht uoy naht releurc eb
#
# OUTPUT
# murbalednaC ddA
#  snomed naht releurc neve ,kniht uoy naht releurc eb n
#
#
# EXAMPLE
#
# INPUT
# rotnevni ot ytngierevoS fo murbalednaC ddA
#  ?yrotnevni ot noitadnuoF f
#
# OUTPUT
# otnevni ot ytngierevoS fo murbalednaC ddA
#  ?yrotnevni ot noitadnuoF fo
#
#
# EXAMPLE
#
# INPUT
# b nac uoy ylno ,lla retfA
#  ?yrotnevni ruoy ot murbalednac hcihw ddA
#  ?
#
# OUTPUT
#  nac uoy ylno ,lla retfA
#  ?yrotnevni ruoy ot murbalednac hcihw ddA
#  ?y
#
#
# EXAMPLE
#
# INPUT
# llaf ,shtap peets gnibmilc retfA
#  ?thgir ,dlrow ruoy fo retnec eht ta
#
# OUTPUT
# laf ,shtap peets gnibmilc retfA
#  ?thgir ,dlrow ruoy fo retnec eht ta e
#
#
# EXAMPLE
#
# INPUT
# fA
#  .yb dessap namuh elamef a ,taht retfA
#  yllanif ,seenk gniparcs ,gn
#
# OUTPUT
# A
#  .yb dessap namuh elamef a ,taht retfA
#  yllanif ,seenk gniparcs ,gni
#
#
# EXAMPLE
#
# INPUT
# otsuc ynam os ton tub ,sool-eekool fo tol a dah ev'ew ,tnedicni eht re
#
# OUTPUT
# tsuc ynam os ton tub ,sool-eekool fo tol a dah ev'ew ,tnedicni eht ret
#
#
# EXAMPLE
#
# INPUT
# inif ew retfA
#  .xetroV a emoceb lliw dlrow eht ,tneve siht retfA
#  .sre
#
# OUTPUT
# nif ew retfA
#  .xetroV a emoceb lliw dlrow eht ,tneve siht retfA
#  .srem
#
#
# EXAMPLE
#
# INPUT
# ew ew retfA
#  .su nopu dnecsed llahs dog s' ydaL ,steppup dum eht ffo h
#
# OUTPUT
# w ew retfA
#  .su nopu dnecsed llahs dog s' ydaL ,steppup dum eht ffo hs
#
#
# EXAMPLE
#
# INPUT
# ,dnuora 'nikop a sraey retfA
#  .gnikniht detrats I ,syaw etarapes ruo t
#
# OUTPUT
# dnuora 'nikop a sraey retfA
#  .gnikniht detrats I ,syaw etarapes ruo tn
#
#
# EXAMPLE
#
# INPUT
# ,edisni tnew uoy retfA
#  tuB !ereh thgir erusaert eht detacol yllanif I
#
# OUTPUT
# edisni tnew uoy retfA
#  tuB !ereh thgir erusaert eht detacol yllanif I
#
#
# EXAMPLE
#
# INPUT
#
#  !em ot klat t'noD t'noD hA
#  !cigam ekil saw tI .pu thgir til yks eht
#
# OUTPUT
#  !em ot klat t'noD t'noD hA
#  !cigam ekil saw tI .pu thgir til yks eht
#
#
# EXAMPLE
#
# INPUT
#
#  .niaga ecno redrum dettimmoc evah I ,hA
#  !nomed a er'uoy won ,tuB !h
#
# OUTPUT
#  .niaga ecno redrum dettimmoc evah I ,hA
#  !nomed a er'uoy won ,tuB !hA
#
#
# EXAMPLE
#
# INPUT
# mih htiw laed ,seixiP revetahw ,hA
#  .ti ot gnir teews a hcus sah ti ,h
#
# OUTPUT
# ih htiw laed ,seixiP revetahw ,hA
#  .ti ot gnir teews a hcus sah ti ,hA
#
#
# EXAMPLE
#
# INPUT
# elba uoy ereW ahahA
#  .su taefed tsum uoy ,kcab reh tnaw uoy fI ahahA
#
#
# OUTPUT
# lba uoy ereW ahahA
#  .su taefed tsum uoy ,kcab reh tnaw uoy fI ahahA
#  !
#
#
# EXAMPLE
#
# INPUT
# w I llA
#  uoy edisni ssenkrad si ees I llA
#  ?ihcustugaK htiw pu peek ot
#
# OUTPUT
#  I llA
#  uoy edisni ssenkrad si ees I llA
#  ?ihcustugaK htiw pu peek ot
#
#
# EXAMPLE
#
# INPUT
# ddus a fo llA
#  etuc tey ,yracS !gniK yradnegel eht ekil eb ot saw detn
#
# OUTPUT
# dus a fo llA
#  etuc tey ,yracS !gniK yradnegel eht ekil eb ot saw detna
#
#
# EXAMPLE
#
# INPUT
# h saw I ,wenk I gniht txen eht dna ,thgil thgirb a yb dednilb saw I ,n
#
# OUTPUT
#  saw I ,wenk I gniht txen eht dna ,thgil thgirb a yb dednilb saw I ,ne
#
#
# EXAMPLE
#
# INPUT
# omed eht fo llA
#  til neeb evah arbalednac eht fo llA
#  .moor siht ni er
#
# OUTPUT
# med eht fo llA
#  til neeb evah arbalednac eht fo llA
#  .moor siht ni ere
#
#
# EXAMPLE
#
# INPUT
#  eht fo llA
#  ,ssenkrad fo nomed wen eht fo htrib eht gnitarbelec era s
#
# OUTPUT
# eht fo llA
#  ,ssenkrad fo nomed wen eht fo htrib eht gnitarbelec era sn
#
#
# EXAMPLE
#
# INPUT
#  uoy edisni tnamrod yal taht rewop eht fo llA
#  .hguoht ,enog era snamu
#
# OUTPUT
# uoy edisni tnamrod yal taht rewop eht fo llA
#  .hguoht ,enog era snamuh
#
#
# EXAMPLE
#
# INPUT
# iaw dna ssenkrad ni dekrul evah ohw uoy fo llA
#  .dehsaelnu neeb won sa
#
# OUTPUT
# aw dna ssenkrad ni dekrul evah ohw uoy fo llA
#  .dehsaelnu neeb won sah
#
#
# EXAMPLE
#
# INPUT
# t ni pu deird sah ytilibissop llA
#  em raeh ,yad siht rof yllufhtiaf de
#
# OUTPUT
#  ni pu deird sah ytilibissop llA
#  em raeh ,yad siht rof yllufhtiaf det
#
#
# EXAMPLE
#
# INPUT
# F ,teppup dum tnagorra taht ffo hsinif ot si tfel s'taht llA
#  dlrow si
#
# OUTPUT
#  ,teppup dum tnagorra taht ffo hsinif ot si tfel s'taht llA
#  dlrow sih
#
#
# EXAMPLE
#
# INPUT
# llA
#  .ereh morf semoc krowteN alamA eht morf ihustagaM eht llA
#  imimot
#
# OUTPUT
# lA
#  .ereh morf semoc krowteN alamA eht morf ihustagaM eht llA
#  imimotu
#
#
# EXAMPLE
#
# INPUT
# naM eht llA
#  .emit eht lla slley eh tahw s'tahT !enim si ihustagaM eht
#
# OUTPUT
# aM eht llA
#  .emit eht lla slley eh tahw s'tahT !enim si ihustagaM eht
#
#
# EXAMPLE
#
# INPUT
# tnatibahni eht llA
#  ecaep ni tser sluos rieht yaM .ereht era snomed ar
#
# OUTPUT
# natibahni eht llA
#  ecaep ni tser sluos rieht yaM .ereht era snomed art
#
#
# EXAMPLE
#
# INPUT
# era artnaM fo srebmem eht llA
#  .gnol erofeb wollof lliw dlrow siht fo
#
# OUTPUT
# ra artnaM fo srebmem eht llA
#  .gnol erofeb wollof lliw dlrow siht fo s
#
#
# EXAMPLE
#
# INPUT
#  .derewol neeb evah srallip eht llA
#  !ihustagaM rieht fo deniard gnieb
#
# OUTPUT
# .derewol neeb evah srallip eht llA
#  !ihustagaM rieht fo deniard gnieb
#
#
# EXAMPLE
#
# INPUT
# llA
#  .evom ot tnaw t'nseod eH .mih ot nettog evah tsum erutrot eht llA
#
# OUTPUT
# lA
#  .evom ot tnaw t'nseod eH .mih ot nettog evah tsum erutrot eht llA
#
#
#
# EXAMPLE
#
# INPUT
# uoy nac sedis htob gniwonk yb ylno dna ,kcab a dna tnorf a evah sgniht
#
# OUTPUT
# oy nac sedis htob gniwonk yb ylno dna ,kcab a dna tnorf a evah sgniht
#
#
# EXAMPLE
#
# INPUT
# t yawa gninnur neeb tsuj ev'uoy ,emit siht llA
#  .meht dnatsrednu ylluf
#
# OUTPUT
#  yawa gninnur neeb tsuj ev'uoy ,emit siht llA
#  .meht dnatsrednu ylluf
#
#
# EXAMPLE
#
# INPUT
# ni elbmert dna edih si od nac ew llA
#  .dniheb gnihtyreve evael ot gniy
#
# OUTPUT
# i elbmert dna edih si od nac ew llA
#  .dniheb gnihtyreve evael ot gniyr
#
#
# EXAMPLE
#
# INPUT
# ht eviecer lliw ew dna ,dog ruo nommus si won od ot evah ew llA
#  !raef
#
# OUTPUT
# t eviecer lliw ew dna ,dog ruo nommus si won od ot evah ew llA
#  !raef
#
#
# EXAMPLE
#
# INPUT
# uoy egduj ot em wollA
#  .siht uoy evig ot em wollA
#  !amijihS fo nosaeR
#
# OUTPUT
# oy egduj ot em wollA
#  .siht uoy evig ot em wollA
#  !amijihS fo nosaeR e
#
#
# EXAMPLE
#
# INPUT
# L thgirlA
#  dnim t'nod uoy fi ,gniht eno uoy llet ot em wollA
#  !!rewop
#
# OUTPUT
#  thgirlA
#  dnim t'nod uoy fi ,gniht eno uoy llet ot em wollA
#  !!rewop r
#
#
# EXAMPLE
#
# INPUT
# l'I !thgirlA
#  !ereh attuo teg s'tel ,neht thgirlA
#  .yaw siht ti od s't
#
# OUTPUT
# 'I !thgirlA
#  !ereh attuo teg s'tel ,neht thgirlA
#  .yaw siht ti od s'te
#
#
# EXAMPLE
#
# INPUT
# t yrt s'tel ,emit sihT !thgirlA
#  !ysae dna ecin ,hguorht teg uoy pleh
#
# OUTPUT
#  yrt s'tel ,emit sihT !thgirlA
#  !ysae dna ecin ,hguorht teg uoy pleh l
#
#
# EXAMPLE
#
# INPUT
# thgirlA
#  !nuf sgniht ekam ot woh wonk uoY !thgirlA
#  !noitamrof-ssorc e
#
# OUTPUT
# hgirlA
#  !nuf sgniht ekam ot woh wonk uoY !thgirlA
#  !noitamrof-ssorc eh
#
#
# EXAMPLE
#
# INPUT
# dausrep ll'I ,thgirlA
#  .ereht attuo uoy teg ot nac I tseb eht od ll'I
#
# OUTPUT
# ausrep ll'I ,thgirlA
#  .ereht attuo uoy teg ot nac I tseb eht od ll'I ,
#
#
# EXAMPLE
#
# INPUT
#  gnihtemos uoy llet ll'I ,thgirlA
#  .hguorht uoy tel ot repeeketag eht
#
# OUTPUT
# gnihtemos uoy llet ll'I ,thgirlA
#  .hguorht uoy tel ot repeeketag eht e
#
#
# EXAMPLE
#
# INPUT
# nol woh s'tahT .eerht ot tnuoc annog m'I ,thgirlA
#  wonk annaw thgim uo
#
# OUTPUT
# ol woh s'tahT .eerht ot tnuoc annog m'I ,thgirlA
#  wonk annaw thgim uoy
#
#
# EXAMPLE
#
# INPUT
# ik tsuj ll'I .pu ti peek ,thgirlA
#  .nalp a htiw pu emoc ot tog ev'uoy
#
# OUTPUT
# k tsuj ll'I .pu ti peek ,thgirlA
#  .nalp a htiw pu emoc ot tog ev'uoy g
#
#
# EXAMPLE
#
# INPUT
# 'tel ,thgirlA
#  .etunim a emmiG .gnihtemos yrt em tel ,thgirlA
#  .kcab k
#
# OUTPUT
# tel ,thgirlA
#  .etunim a emmiG .gnihtemos yrt em tel ,thgirlA
#  .kcab kc
#
#
# EXAMPLE
#
# INPUT
# kciP .erom eno ,thgirlA
#  ?thgir ,tnenoppo ruoy tuoba saw tI .eunitnoc
#
# OUTPUT
# ciP .erom eno ,thgirlA
#  ?thgir ,tnenoppo ruoy tuoba saw tI .eunitnoc s
#
#
# EXAMPLE
#
# INPUT
# ythgirlA
#  ?ydaer uoY !ti rof llef yeht ,thgirlA
#  .ekil ay taht eno yna
#
# OUTPUT
# thgirlA
#  ?ydaer uoY !ti rof llef yeht ,thgirlA
#  .ekil ay taht eno yna
#
#
# EXAMPLE
#
# INPUT
# vitucexe pot eht , ,oslA
#  !regnol elttil a uoy htiw yats ll'I sseug I
#
# OUTPUT
# itucexe pot eht , ,oslA
#  !regnol elttil a uoy htiw yats ll'I sseug I !
#
#
# EXAMPLE
#
# INPUT
# cco netfo stnedicca ,oslA
#  .gnissim llits si ,noitacinummoC srebyC fo
#
# OUTPUT
# co netfo stnedicca ,oslA
#  .gnissim llits si ,noitacinummoC srebyC fo e
#
#
# EXAMPLE
#
# INPUT
#  nomed a pu level uoy fi ,oslA
#  .tsethgirb sti ta si ihcustugaK nehw r
#
# OUTPUT
# nomed a pu level uoy fi ,oslA
#  .tsethgirb sti ta si ihcustugaK nehw ru
#
#
# EXAMPLE
#
# INPUT
# ni ,oslA
#  .level taht ta ti nommus ot elba eb lliw uoy ,ti retsiger dn
#
# OUTPUT
# i ,oslA
#  .level taht ta ti nommus ot elba eb lliw uoy ,ti retsiger dna
#
#
# EXAMPLE
#
# INPUT
#  uoy naht nomed tnereffid yletelpmoc a htiw pu dne yam uoy ,sesac emos
#
# OUTPUT
# uoy naht nomed tnereffid yletelpmoc a htiw pu dne yam uoy ,sesac emos
#
#
# EXAMPLE
#
# INPUT
#
#  .su edisgnola thgif ot si ynitsed ruoy eveileb I ,hguohtlA
#  .detcepx
#
# OUTPUT
#  .su edisgnola thgif ot si ynitsed ruoy eveileb I ,hguohtlA
#  .detcepxe
#
#
# EXAMPLE
#
# INPUT
# ?evac a ni efil nomed ruoy lla gnivil neeb uoy evaH ?railucep taht I m
#
# OUTPUT
# evac a ni efil nomed ruoy lla gnivil neeb uoy evaH ?railucep taht I mA
#
#
# EXAMPLE
#
# INPUT
# lacideM :krowteN alamA
#  lanimret-bus F5 retneC lacideM :krowteN alamA
#
#
# OUTPUT
# acideM :krowteN alamA
#  lanimret-bus F5 retneC lacideM :krowteN alamA
#
#
#
# EXAMPLE
#
# INPUT
# wakiH rednammoC epoh I ?raf siht tog redurtni nA
#  lanimret niam retneC
#
# OUTPUT
# akiH rednammoC epoh I ?raf siht tog redurtni nA
#  lanimret niam retneC
#
#
# EXAMPLE
#
# INPUT
# rrac lliw enola I dnA
#  .taht fo pot no ,me' fo 4 dnA
#  !gnippils t'nsi
#
# OUTPUT
# rac lliw enola I dnA
#  .taht fo pot no ,me' fo 4 dnA
#  !gnippils t'nsi a
#
#
# EXAMPLE
#
# INPUT
#  wonk t'nod I dnA
#  !eno ylno eht ton ma I dnA
#  .nis sti fo nedrub eht
#
# OUTPUT
# wonk t'nod I dnA
#  !eno ylno eht ton ma I dnA
#  .nis sti fo nedrub eht y
#
#
# EXAMPLE
#
# INPUT
# lf eht pom ,naem I dnA
#  nrober teg seod ti nehw ekil eb annog s'ti tah
#
# OUTPUT
# f eht pom ,naem I dnA
#  nrober teg seod ti nehw ekil eb annog s'ti tahw
#
#
# EXAMPLE
#
# INPUT
# oL thgir saw I dnA
#  .pleh s'ydobyna tuohtiw yaw eht denepo I dnA
#  !!ro
#
# OUTPUT
# L thgir saw I dnA
#  .pleh s'ydobyna tuohtiw yaw eht denepo I dnA
#  !!roo
#
#
# EXAMPLE
#
# INPUT
# evo sehctaw taht thgil eht ,ihcustugaK dnA
#  .topkcaj eht tih I ekil sk
#
# OUTPUT
# vo sehctaw taht thgil eht ,ihcustugaK dnA
#  .topkcaj eht tih I ekil sko
#
#
# EXAMPLE
#
# INPUT
# oc dellac ew taht esoht lla dnA
#  noitaerc sa llew sa dlroW xetroV eht
#
# OUTPUT
# c dellac ew taht esoht lla dnA
#  noitaerc sa llew sa dlroW xetroV eht r
#
#
# EXAMPLE
#
# INPUT
# eh dnA
#  ,ti no slobmys eht gnirehpiced yb dnA
#  .su detresed evah sedar
#
# OUTPUT
# h dnA
#  ,ti no slobmys eht gnirehpiced yb dnA
#  .su detresed evah sedarm
#
#
# EXAMPLE
#
# INPUT
# dnik tahw gnirednow saw I ereh dnA
#  .erus rof s'taht ,ti fo stol tog s
#
# OUTPUT
# nik tahw gnirednow saw I ereh dnA
#  .erus rof s'taht ,ti fo stol tog s'
#
#
# EXAMPLE
#
# INPUT
# oy fi dnA
#  !dlihc sselmrah a ylno er'uoy ,yhW gnissapsert saw nomed fo
#
# OUTPUT
# y fi dnA
#  !dlihc sselmrah a ylno er'uoy ,yhW gnissapsert saw nomed fo
#
#
# EXAMPLE
#
# INPUT
# rt uoy fi dnA
#  uoy tsissa ot lleh fo shtped eht morf esir lliw I llac
#
# OUTPUT
# t uoy fi dnA
#  uoy tsissa ot lleh fo shtped eht morf esir lliw I llac u
#
#
# EXAMPLE
#
# INPUT
# ti dnA
#  !elbuort erom neve otni nur ll'uoy ,hguorht yaw ruoy ecrof ot
#
# OUTPUT
# i dnA
#  !elbuort erom neve otni nur ll'uoy ,hguorht yaw ruoy ecrof ot y
#
#
# EXAMPLE
#
# INPUT
# b gnigduj dnA
#  .noitpecnoC eht hguorht evil lliw uoy taht etaf ruoy si
#
# OUTPUT
#  gnigduj dnA
#  .noitpecnoC eht hguorht evil lliw uoy taht etaf ruoy si
#
#
# EXAMPLE
#
# INPUT
# 'ereht ,yltsal dnA
#  .rewop elbaredisnoc deniag ev'uoy ecnaraeppa ruoy
#
# OUTPUT
# ereht ,yltsal dnA
#  .rewop elbaredisnoc deniag ev'uoy ecnaraeppa ruoy y
#
#
# EXAMPLE
#
# INPUT
#  krowten taht ylekil tsom dnA
#  .niw ot esu ot erus ekaM .nomed erif a
#
# OUTPUT
# krowten taht ylekil tsom dnA
#  .niw ot esu ot erus ekaM .nomed erif a s
#
#
# EXAMPLE
#
# INPUT
# fo noigel eritne nA taht tsuj ton dnA
#  .si awakiH erehw ot detcennoc s
#
# OUTPUT
# o noigel eritne nA taht tsuj ton dnA
#  .si awakiH erehw ot detcennoc si
#
#
# EXAMPLE
#
# INPUT
# ops ni tsetal eht rof ieK ot revo ,won dnA
#  !uoy stiawa spoort tseb ym
#
# OUTPUT
# ps ni tsetal eht rof ieK ot revo ,won dnA
#  !uoy stiawa spoort tseb ym
#
#
# EXAMPLE
#
# INPUT
# s a nrob neeb evah uoy ,won dnA
#  .htaed reh tem sah emit ,won dnA
#  !st
#
# OUTPUT
#  a nrob neeb evah uoy ,won dnA
#  .htaed reh tem sah emit ,won dnA
#  !str
#
#
# EXAMPLE
#
# INPUT
# l skool eno rehto eht dnA
#  .eb lliw awakiH erehw s'taht dnA
#  emit dnoc
#
# OUTPUT
#  skool eno rehto eht dnA
#  .eb lliw awakiH erehw s'taht dnA
#  emit dnoce
# EXAMPLE
#
# INPUT
# nA
#  ytilaer a tolp sih ekam ot elba saw eh nosaer eht dnA
#  .ssorc a ek
#
# OUTPUT
# A
#  ytilaer a tolp sih ekam ot elba saw eh nosaer eht dnA
#  .ssorc a eki
#
#
# EXAMPLE
#
# INPUT
# rb eht no sthgil esoht dnA
#  .kaeps ew sa neve ,no segar llits raw eht
#
# OUTPUT
# b eht no sthgil esoht dnA
#  .kaeps ew sa neve ,no segar llits raw eht d
#
#
# EXAMPLE
#
# INPUT
# iknam fo epocs eht dnoyeb dehcaer eh ,yletamitlu dnA
#  .seixiP era segd
#
# OUTPUT
# knam fo epocs eht dnoyeb dehcaer eh ,yletamitlu dnA
#  .seixiP era segdi
#
#
# EXAMPLE
#
# INPUT
# eurt semoc hsiw sih nehw dnA
#  .dlrow eht fo noitaerc eht dettolp dna d
#
# OUTPUT
# urt semoc hsiw sih nehw dnA
#  .dlrow eht fo noitaerc eht dettolp dna dn
#
#
# EXAMPLE
#
# INPUT
# kcatta t'nerew uoy dnA
#  .taht hsilpmocca lliw ohw eno eht era uoy dnA
#
#
# OUTPUT
# catta t'nerew uoy dnA
#  .taht hsilpmocca lliw ohw eno eht era uoy dnA
#
#
#
# EXAMPLE
#
# INPUT
# ioj yllautneve llahs uoy ,dnA
#  meht retfa pu naelc I ,dnA
#  ???ino yb d
#
# OUTPUT
# oj yllautneve llahs uoy ,dnA
#  meht retfa pu naelc I ,dnA
#  ???ino yb de
#
#
# EXAMPLE
#
# INPUT
# o yrotirret eht retne ohw ynA
#  .yarp su tel ,woN efilretfa eht ni mih
#
# OUTPUT
#  yrotirret eht retne ohw ynA
#  .yarp su tel ,woN efilretfa eht ni mih n
#
#
# EXAMPLE
#
# INPUT
# eroc eht si siht taht emussa dluow ydobynA
#  .deirt eb lliw artnaM eht
#
# OUTPUT
# roc eht si siht taht emussa dluow ydobynA
#  .deirt eb lliw artnaM eht f
#
#
# EXAMPLE
#
# INPUT
#  ,yawynA
#  .alamA fo naeco tsav eht ni elbissop si gnihtynA
#  .olihiN fo
#
# OUTPUT
# ,yawynA
#  .alamA fo naeco tsav eht ni elbissop si gnihtynA
#  .olihiN fo
#
#
# EXAMPLE
#
# INPUT
# A
#  !enoyreve ot siht troper s'tel ,yawynA
#  ?yako ,gnitiaw su peek t'no
#
# OUTPUT
#
#  !enoyreve ot siht troper s'tel ,yawynA
#  ?yako ,gnitiaw su peek t'nod
#
#
# EXAMPLE
#
# INPUT
# t ni eveileb yeht ,yawynA
#  !tseb eht eb ot gnimia m'I niaga ecno ,yawy
#
# OUTPUT
#  ni eveileb yeht ,yawynA
#  !tseb eht eb ot gnimia m'I niaga ecno ,yawyn
#
#
# EXAMPLE
#
# INPUT
# tsurtne I syawynA
#  .ukoriM fo erutpircS eht dellac ycehporp fo koob si
#
# OUTPUT
# surtne I syawynA
#  .ukoriM fo erutpircS eht dellac ycehporp fo koob sih
#
#
# EXAMPLE
#
# INPUT
# yako er'uoy taht ees ot dalg m'I ,syawynA
#  .lliB taht gnidnif htiw uoy
#
# OUTPUT
# ako er'uoy taht ees ot dalg m'I ,syawynA
#  .lliB taht gnidnif htiw uoy
#
#
# EXAMPLE
#
# INPUT
# us s'olihiN rednu t'nsi ereh lanimret eht ,detcepsus I ekil ,syawynA
#
#
# OUTPUT
# s s'olihiN rednu t'nsi ereh lanimret eht ,detcepsus I ekil ,syawynA
#  .
#
#
# EXAMPLE
#
# INPUT
#  revo enoemos teG !ikaihC rof emit eht t'nsi siht ,syawynA
#  .ecnalliev
#
# OUTPUT
# revo enoemos teG !ikaihC rof emit eht t'nsi siht ,syawynA
#  .ecnallievr
#
#
# EXAMPLE
#
# INPUT
# !!ni eveileb ew tahw rof thgif tsum eW !rewsna eht ton si yhtapA
#  !ere
#
# OUTPUT
# !ni eveileb ew tahw rof thgif tsum eW !rewsna eht ton si yhtapA
#  !ereh

# %%
BATCH_SIZE = 64
VOCAB_SIZE = len(vocab)  # vocab is number of unique characters
EMBEDDING_DIM = 256
RNN_UNITS = 1024

# Buffer size to shuffle the dataset
# (TF data is designed to work with possibly infinite sequences,
# so it doesn't attempt to shuffle the entire sequence in memory. Instead,
# it maintains a buffer in which it shuffles elements).
BUFFER_SIZE = 10000

# %%
data = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)

# %%
data = dataset_left.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)

# %%
model = build_model(VOCAB_SIZE,EMBEDDING_DIM, RNN_UNITS, BATCH_SIZE)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (64, None, 256)           18944
# _________________________________________________________________
# lstm (LSTM)                  (64, None, 1024)          5246976
# _________________________________________________________________
# dense (Dense)                (64, None, 74)            75850
# =================================================================
# Total params: 5,341,770
# Trainable params: 5,341,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
for input_example_batch, target_example_batch in data.take(1):
  example_batch_predictions = model(input_example_batch)  # ask our model for a prediction on our first batch of training data (64 entries)
  print(example_batch_predictions.shape, "# (batch_size, sequence_length, vocab_size)")  # print out the output shape
# Out:
# (64, 70, 74) # (batch_size, sequence_length, vocab_size)

# %%
model.compile(optimizer='adam', loss=loss)

# %%
# Directory where the checkpoints will be saved
#WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#https://stackoverflow.com/questions/52776622/keras-callbacks-keep-skip-saving-checkpoints-claiming-val-acc-is-missing
checkpoint_dir = 'cleaner_script_Model_left.hdf5'
# Name of the checkpoint files
#checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}")
#checkpoint_prefix = os.path.join(checkpoint_dir, "model.hdf5")

checkpoint_callback=tf.keras.callbacks.ModelCheckpoint(
    monitor='loss',
    mode='min',
    filepath=checkpoint_dir,
    save_best_only=True,
    save_weights_only=True,
    save_freq=2
)

# %%
#Training the model. we set the runtime to > GPU to speed up this process
history = model.fit(data, epochs=200, callbacks=[checkpoint_callback])
# Out:
# Epoch 1/200
# 15/70 [=====>........................] - ETA: 2:48 - loss: 3.5375
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-5b82221592cf> in <module>
#       1 #Training the model. we set the runtime to > GPU to speed up this process
# ----> 2 history = model.fit(data, epochs=200, callbacks=[checkpoint_callback])
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
model = build_model(VOCAB_SIZE, EMBEDDING_DIM, RNN_UNITS, batch_size=1)

# %%
#tf.keras.models.load_model('/','FatherTimeModel.hdf5', custom_objects=None, compile=True)
model.build(tf.TensorShape([1, None]))

# %%
#This line was ommited from the visual demo. It's here for reference, 
#however it should have been checked to be working. As it is not.
checkpoint_num = 10
model.load_weights(tf.train.load_checkpoint("./training_checkpoints/ckpt_" + str(checkpoint_num)))
model.build(tf.TensorShape([1, None]))

# %%
modelR = build_model(VOCAB_SIZE, EMBEDDING_DIM, RNN_UNITS, batch_size=1)
modelL = build_model(VOCAB_SIZE, EMBEDDING_DIM, RNN_UNITS, batch_size=1)
modelL.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (1, None, 256)            18944
# _________________________________________________________________
# lstm_2 (LSTM)                (1, None, 1024)           5246976
# _________________________________________________________________
# dense_2 (Dense)              (1, None, 74)             75850
# =================================================================
# Total params: 5,341,770
# Trainable params: 5,341,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
#We're changing the shape, but loading the weights of our trained model
#model.load_weights(tf.train.latest_checkpoint('FatherTimeModel.hdf5'))
modelR.load_weights('cleaner_script_Model_right.hdf5')
modelL.load_weights('cleaner_script_Model_left.hdf5')

# %%
modelR.build(tf.TensorShape([1, None]))
modelL.build(tf.TensorShape([1, None]))

# %%
def generate_text(model, start_string):
  # Evaluation step (generating text using the learned model)

  # Number of characters to generate
  num_generate = 200

  # Converting our start string to numbers (vectorizing)
  input_eval = [char2idx[s] for s in start_string]
  input_eval = tf.expand_dims(input_eval, 0)

  # Empty string to store our results
  text_generated = []

  # Low temperatures results in more predictable text.
  # Higher temperatures results in more surprising text.
  # Experiment to find the best setting.
  temperature = 1.0

  # Here batch size == 1
  model.reset_states()
  for i in range(num_generate):
      predictions = model(input_eval)
        
      # remove the batch dimension 
      # squeeze take the nested arrays of [[]] and removes them
      predictions = tf.squeeze(predictions, 0)

      # using a categorical distribution to predict the character returned by the model
      predictions = predictions / temperature
      predicted_id = tf.random.categorical(predictions, num_samples=1)[-1,0].numpy()

      # We pass the predicted character as the next input to the model
      # along with the previous hidden state
      input_eval = tf.expand_dims([predicted_id], 0)      
      text_generated.append(idx2char[predicted_id])

  return (start_string + ''.join(text_generated))

# %%
def generate_text_dual(modelL, modelR, start_string):
  # Evaluation step (generating text using the learned model)

  # Number of characters to generate
  num_generate = 100

  # Converting our start string to numbers (vectorizing)
  input_eval_R = [char2idx[s] for s in start_string]
  input_eval_R = tf.expand_dims(input_eval_R, 0)
  input_eval_L = [char2idx[s] for s in start_string]
  input_eval_L = tf.expand_dims(input_eval_L, 0)

  # Empty string to store our results
  text_generated = [start_string]

  # Low temperatures results in more predictable text.
  # Higher temperatures results in more surprising text.
  # Experiment to find the best setting.
  temperature = 0.5

  # Here batch size == 1
  modelR.reset_states()
  modelL.reset_states()
  for i in range(num_generate):
      predictions_R = modelR(input_eval_R)
      predictions_L = modelL(input_eval_L)
        
      # remove the batch dimension 
      # squeeze take the nested arrays of [[]] and removes them
      predictions_R = tf.squeeze(predictions_R, 0)
      predictions_L = tf.squeeze(predictions_L, 0)

      # using a categorical distribution to predict the character returned by the model
      predictions_R = predictions_R / temperature
      predictions_L = predictions_L / temperature
      predicted_id_R = tf.random.categorical(predictions_R, num_samples=1)[-1,0].numpy()
      predicted_id_L = tf.random.categorical(predictions_L, num_samples=1)[-1,0].numpy()

      # We pass the predicted character as the next input to the model
      # along with the previous hidden state
      input_eval_R = tf.expand_dims([predicted_id_R], 0)
      input_eval_L = tf.expand_dims([predicted_id_L], 0)
      
      text_generated.append(idx2char[predicted_id_R])
      text_generated.insert(0, idx2char[predicted_id_L])

  return (''.join(text_generated))

# %%
def generate_text_left(model, start_string):
  # Evaluation step (generating text using the learned model)

  # Number of characters to generate
  num_generate = 200

  # Converting our start string to numbers (vectorizing)
  input_eval = [char2idx[s] for s in start_string]
  input_eval = tf.expand_dims(input_eval, 0)

  # Empty string to store our results
  text_generated = [start_string]

  # Low temperatures results in more predictable text.
  # Higher temperatures results in more surprising text.
  # Experiment to find the best setting.
  temperature = 1.0

  # Here batch size == 1
  model.reset_states()
  for i in range(num_generate):
      predictions = model(input_eval)
        
      # remove the batch dimension 
      # squeeze take the nested arrays of [[]] and removes them
      predictions = tf.squeeze(predictions, 0)

      # using a categorical distribution to predict the character returned by the model
      predictions = predictions / temperature
      predicted_id = tf.random.categorical(predictions, num_samples=1)[-1,0].numpy()

      # We pass the predicted character as the next input to the model
      # along with the previous hidden state
      input_eval = tf.expand_dims([predicted_id], 0)
      
      text_generated.insert(0, idx2char[predicted_id])

  return (''.join(text_generated))

# %%
#Father Time tests Temp 1.0
inp = input("Type a starting string: ")

print(generate_text_dual(modelL, modelR, inp))
# Out:
# Type a starting string: time
# mmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmbmbmbtimelous my whe Will returay of unayncare of wher you tell bef formyot.
# If you exproing ons meats me. Y

# %%
#Father Time tests Temp 1.0
inp = input("Type a starting string: ")

print(generate_text_left(modelL, inp))
# Out:
# Type a starting string: time
# ACTCvS8P-U8PPKKG.LKLL.L.
#
#
#
#
# vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvevevevevtime

# %%
#Type left tests Temp 1.0
inp = input("Type a starting string: ")

print(generate_text_left(modelL, inp))
# Out:
# Type a starting string: answer
# g from inside the home of thisky, but it's better feel the presence of superior is the seeds of creation, denying the reincarnation of the world.
# Phew! We it with demon was worried for nothing. Now, answer

# %%
#type dual tests Temp 0.5
inp = input("Type a starting string: ")

print(generate_text_dual(modelL, modelR, inp))
# Out:
# Type a starting string:  return
#  well
# Man can change the wore junk in our way.
# Sorry, but I can't help you right now. I need to co return all the candelabra to the Labyrinth of Amala.
# I know the name of Nihilo.
# I'm not really in the Co

# %%
def generate_sentence(modelL, modelR, start_string):
    # Low temperatures results in more predictable text.
    # Higher temperatures results in more surprising text.
    temperature = 0.8
    # Max number of characters to generate in either direction
    num_generate = 100
    
    # reversing the starting string when using the left model as the model is built in reverse, then vectorize
    rev_string = reverse_string(start_string)
    input_eval_L = [char2idx[s] for s in rev_string]
    input_eval_L = tf.expand_dims(input_eval_L, 0)

    # Empty string to store our results
    text_generated = [start_string]
    
    modelL.reset_states()
    #Generate text to the left
    for i in range(num_generate):
        predictions_L = modelL(input_eval_L)
        predictions_L = tf.squeeze(predictions_L, 0)
        predictions_L = predictions_L / temperature
        predicted_id_L = tf.random.categorical(predictions_L, num_samples=1)[-1,0].numpy()

        input_eval_L = tf.expand_dims([predicted_id_L], 0)
        character = idx2char[predicted_id_L]
        #if period, remove it, and the following space then end
        if character == '.' or character == '?' or character == '!':
            text_generated.pop(0)
            break
        text_generated.insert(0, idx2char[predicted_id_L])
    
    # update our string to include the text we've generated
    start_string = ''.join(text_generated)
    input_eval_R = [char2idx[s] for s in start_string]
    input_eval_R = tf.expand_dims(input_eval_R, 0)
    
    modelR.reset_states()    
    #`generate text to the right
    for i in range(num_generate):
        predictions_R = modelR(input_eval_R)
        predictions_R = tf.squeeze(predictions_R, 0)
        predictions_R = predictions_R / temperature
        predicted_id_R = tf.random.categorical(predictions_R, num_samples=1)[-1,0].numpy()

        input_eval_R = tf.expand_dims([predicted_id_R], 0)
        character = idx2char[predicted_id_R]
        text_generated.append(idx2char[predicted_id_R])
        #If period, add to array then end
        if character == '.' or character == '?' or character == '!':
            break

    return (''.join(text_generated))

def reverse_string(string):
    reversedString = ""
    for r in range(len(string)-1,-1,-1):
        reversedString += string[r]
    return reversedString

# %%
inp = input("Type a starting string: ")
print(generate_sentence(modelL, modelR, inp))
# Out:
# Type a starting string: life
#
# When you have dlife can see your heart, but inside there is nothing.

# %%
inp = input("Type a starting string: ")
print(generate_sentence(modelL, modelR, inp))
# Out:
# Type a starting string: life
# life
#
# one life and fulfill the part which you were originally intended for.

# %%
inp = input("Type a starting string: ")
print(generate_sentence(modelL, modelR, inp))
# Out:
# Type a starting string: think
# think
# What the hell are you thinking about coming up with a Reason.

# %%
inp = input("Type a starting string: ")
print(generate_sentence(modelL, modelR, inp))
# Out:
# Type a starting string: the answer
#
# If you can reach the top, you should ckill the answer to the unanswerable question, Why is a world reborn?

# %%
inp = input("Type a starting string: ")
print(generate_sentence(modelL, modelR, inp))
# Out:
# Type a starting string: I'm thinkin
#
# That's why I'm thinking, and I'm going to continue on with my life.

# %%
inp = input("Type a starting string: ")
print(generate_sentence(modelL, modelR, inp))
# Out:
# Type a starting string: I'm thinkin
#
# That's why I'm thinking, but
# I had not to be functioning, even though the switch for really thinks of you.

# %%
inp = input("Type a starting string: ")
print(generate_sentence(modelL, modelR, inp))
# Out:
# Type a starting string: the important thing
#
# I found the important things like this thing can keep record of your progress.

# %%
the treasure
